# %% [markdown]
# <hr style="margin-top:0px;height:18px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %%
from generating_utils import *
from CONSTS_GENERALVARS.models_vars import MODELS_IMPORTS, MODELS_FUNCTION_DEFINITIONS
import datetime

# %%
import csv
with open("variable_hierarchy.csv", "w") as my_file:
    writer = csv.writer(my_file)
    writer.writerow(["variable", "section", "subsection", "subsubsection"])
    for item in list(vars_dic.keys()):
        row = [item, " ", "", ""] 
        writer.writerow(row)
#vars_dic.keys()

# %% [markdown]
# # VARS_DIC
#
# ### I need to make vars_dic
# ### Before that, I need to decide on the data model. I do that by populating two empty dataframes:
# - vars_df: `has all the info on main vars and classes in models.py`
# - cols_df: `has all the columns of interest of all the models`
#
# ### The two dfs above then collaborate to create the vars_dic
#
# #### Remember: For now `vars_dic` present in crisisdb_vars is imported from the `csv_cleaner.ipynb` and its `resulting_vars_dic` after some shenanygans. Room for improvement there.

# %%
 meta_cols_in_variables = [
        "varname", "db_name", "main_desc", "main_desc_source", "notes", "cols", "section", "subsection", "needsSeshatCommon",
    ]
my_dic = {}    
for item in meta_cols_in_variables:
    my_dic[item] = None

# %%
my_dic

# %% [markdown]
# # Models
# ####  Things to be done:
# - `choices_tuples.py` must be created dynamically. Otherwise it is of no use.
# - Make sure `importrtance` is taken care of.
# - Make sure `vardesc` and `maindesc` and `Section` and `Subsection` are all compaticle with the other files. That might include removing section nad subsection from seshatcommon all together.
# - Make sure **`decimal_points`** and other variable-dependent are taken care of decently.
#
# #### Remember: For now `vars_dic` present in crisisdb_vars is imported from the `csv_cleaner.ipynb` and its `resulting_vars_dic` after some shenanygans. Room for improvement there.
#
# # Remember: For now `general_vars_dic_new` present in general_vars is imported from the `general_vars.py`. But how is this one created again??

# %%
from generating_utils import *
from CONSTS_GENERALVARS.models_vars import MODELS_IMPORTS, MODELS_FUNCTION_DEFINITIONS
import datetime
now = datetime.datetime.now()
nowstr = now.strftime("%Y_%m_%d_%H%M")

all_model_strs = MODELS_IMPORTS + tuple_choices_maker(general_vars_dic_new) + MODELS_FUNCTION_DEFINITIONS + model_generator(general_vars_dic_new)
output_folder = "outputs/general/output_models"
make_sure_exists(output_folder)

file_name = output_folder + "/models.py" 

with open(file_name, "w") as text_file:
    text_file.write(all_model_strs)
    print(f"Voila... {file_name}: Done")

# %% [markdown]
# ### When you are happy with the result of the models.py generated, Run the bash script that does the transferring of the info
# <hr style="margin-top:0px;height:4px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">
#
# Two things to do:
# - uncomment the destination_abs_dir line in the `.sh` script.
# - uncomment the `mv` line here.

# %%
# Replace the old models.py file with a models_2022_xyz.py file
# !mv /home/majid/dev/seshat/seshat/seshat/apps/general/models.py /home/majid/dev/seshat/seshat/seshat/apps/general/models_{nowstr}.py 

# make the bash script executable and execute it:
# !chmod +x BASH_SCRIPTS_GENERAL/make_models_for_general.sh
# !BASH_SCRIPTS_GENERAL/make_models_for_general.sh

# %% [markdown]
# <hr style="margin-top:0px;height:66px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %% [markdown]
# # Serializers

# %%
from generating_utils import *
from CONSTS_GENERALVARS.serializers_vars import SERIALIZERS_FUNCTION_DEFINITIONS
import datetime
now = datetime.datetime.now()
nowstr = now.strftime("%Y_%m_%d_%H%M")

# str_polity_serializer = polity_serializer_generator(vars_dic)
# str_other_serializers = serial_generator(vars_dic)

all_serializer_strs = all_imports_generator_for_serializers(general_vars_dic_new) + SERIALIZERS_FUNCTION_DEFINITIONS + serial_generator(general_vars_dic_new) + polity_serializer_generator(general_vars_dic_new)
output_folder = "outputs/general/output_serializers"
make_sure_exists(output_folder)

file_name = output_folder + "/serializers.py" 

with open(file_name, "w") as text_file:
    text_file.write(all_serializer_strs)
    print(f"Voila... {file_name}: Done")

# %% [markdown]
# ### Run the bash script that does the transferring of the info
# <hr style="margin-top:0px;height:4px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">
#
# Two things to do:
# - uncomment the destination_abs_dir line in the `.sh` script.
# - uncomment the `mv` line here.

# %%
# Replace the old serializers.py file with a serializers_2022_xyz.py file
# !mv /home/majid/dev/seshat/seshat/seshat/apps/seshat_api/serializers.py /home/majid/dev/seshat/seshat/seshat/apps/seshat_api/serializers_{nowstr}.py 

# make the bash script executable and execute it:
# !chmod +x BASH_SCRIPTS_GENERAL/make_serializers_for_seshat_api.sh
# !BASH_SCRIPTS_GENERAL/make_serializers_for_seshat_api.sh

# %% [markdown]
# <hr style="margin-top:0px;height:66px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %% [markdown]
# # Forms

# %%
from generating_utils import *
from CONSTS_GENERALVARS.forms_vars import FORMS_IMPORTS
import datetime
now = datetime.datetime.now()
nowstr = now.strftime("%Y_%m_%d_%H%M")

all_forms_strs = all_models_imports_generator(general_vars_dic_new) + FORMS_IMPORTS + form_generator(general_vars_dic_new)
output_folder = "outputs/general/output_forms"
make_sure_exists(output_folder)

file_name = output_folder + "/forms.py" 
with open(file_name, "w") as text_file:
    text_file.write(all_forms_strs)
    print(f"Voila... {file_name}: Done")

# %% [markdown]
# ### Run the bash script that does the transferring of the info
# <hr style="margin-top:0px;height:4px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">
#
# Two things to do:
# - uncomment the destination_abs_dir line in the `.sh` script.
# - uncomment the `mv` line here.

# %%
# Replace the old models.py file with a models_2022_xyz.py file
# !mv /home/majid/dev/seshat/seshat/seshat/apps/general/forms.py /home/majid/dev/seshat/seshat/seshat/apps/general/forms_{nowstr}.py 

# make the bash script executable and execute it:
# !chmod +x BASH_SCRIPTS_GENERAL/make_forms_for_general.sh
# !BASH_SCRIPTS_GENERAL/make_forms_for_general.sh

# %% [markdown]
# <hr style="margin-top:0px;height:66px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %% [markdown]
# # URLs

# %%
from generating_utils import *
from CONSTS_GENERALVARS.urls_vars import URL_BASE_IMPORTS
import datetime
now = datetime.datetime.now()
nowstr = now.strftime("%Y_%m_%d_%H%M")

all_urls_strs = all_models_imports_generator(general_vars_dic_new) + URL_BASE_IMPORTS + url_generator(general_vars_dic_new)
output_folder = "outputs/general/output_urls"
make_sure_exists(output_folder)

file_name = output_folder + "/urls.py" 

with open(file_name, "w") as text_file:
    text_file.write(all_urls_strs)
    print(f"Voila... {file_name}: Done")

# %% [markdown]
# ### Run the bash script that does the transferring of the info
# <hr style="margin-top:0px;height:4px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">
#
# Two things to do:
# - uncomment the destination_abs_dir line in the `.sh` script.
# - uncomment the `mv` line here.

# %%
# Replace the old models.py file with a models_2022_xyz.py file
# !mv /home/majid/dev/seshat/seshat/seshat/apps/general/urls.py /home/majid/dev/seshat/seshat/seshat/apps/general/urls_{nowstr}.py 

# make the bash script executable and execute it:
# !chmod +x BASH_SCRIPTS_GENERAL/make_urls_for_general.sh
# !BASH_SCRIPTS_GENERAL/make_urls_for_general.sh

# %% [markdown]
# <hr style="margin-top:0px;height:66px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %% [markdown]
# # Admins

# %%
from generating_utils import *
import datetime
now = datetime.datetime.now()
nowstr = now.strftime("%Y_%m_%d_%H%M")

all_admins_strs = admin_generator(general_vars_dic_new)
output_folder = "outputs/general/output_admin"
make_sure_exists(output_folder)

file_name = output_folder + "/admin.py" 

with open(file_name, "w") as text_file:
    text_file.write(all_admins_strs)
    print(f"Voila... {file_name}: Done")

# %% [markdown]
# ### Run the bash script that does the transferring of the info
# <hr style="margin-top:0px;height:4px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">
#
# Two things to do:
# - uncomment the destination_abs_dir line in the `.sh` script.
# - uncomment the `mv` line here.

# %%
# Replace the old models.py file with a models_2022_xyz.py file
# !mv /home/majid/dev/seshat/seshat/seshat/apps/general/admin.py /home/majid/dev/seshat/seshat/seshat/apps/general/admin_{nowstr}.py 

# make the bash script executable and execute it:
# !chmod +x BASH_SCRIPTS_GENERAL/make_admin_for_general.sh
# !BASH_SCRIPTS_GENERAL/make_admin_for_general.sh

# %% [markdown]
# <hr style="margin-top:0px;height:66px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %% [markdown]
# # VIEWs

# %% [markdown]
# ### TODO:
# - make sure sections and subsections are also dynamically generated and put int vars_dic for use in views in qing_vars.html

# %%
from generating_utils import *
# from CONSTS_GENERALVARS.views_vars import VIEWS_IMPORTS, QING_VARS_FUNC, PLAYGROUND_FUNCS
from CONSTS_GENERALVARS.views_vars import VIEWS_IMPORTS
import datetime
import os
now = datetime.datetime.now()
nowstr = now.strftime("%Y_%m_%d_%H%M")

#all_views_str = VIEWS_IMPORTS + view_generator(general_vars_dic_new) + QING_VARS_FUNC + PLAYGROUND_FUNCS
all_views_str = VIEWS_IMPORTS + view_generator(general_vars_dic_new) + general_VARS_MAKER("general", general_vars_dic_new)

output_folder = "outputs/general/output_views"
make_sure_exists(output_folder)

file_name = output_folder + "/views.py" 

with open(file_name, "w") as text_file:
    text_file.write(all_views_str)
    print(f"Voila... {file_name}: Done")

# %% [markdown]
# ### Run the bash script that does the transferring of the info
# <hr style="margin-top:0px;height:4px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">
#
# Two things to do:
# - uncomment the destination_abs_dir line in the `.sh` script.
# - uncomment the `mv` line here.

# %%
# Replace the old models.py file with a models_2022_xyz.py file
# !mv /home/majid/dev/seshat/seshat/seshat/apps/general/views.py /home/majid/dev/seshat/seshat/seshat/apps/general/views_{nowstr}.py 

# make the bash script executable and execute it:
# !chmod +x BASH_SCRIPTS_GENERAL/make_views_for_general.sh
# !BASH_SCRIPTS_GENERAL/make_views_for_general.sh

# %% [markdown]
# <hr style="margin-top:0px;height:66px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %% [markdown]
# # Templates

# %%
from generating_utils import *
import datetime
now = datetime.datetime.now()
nowstr = now.strftime("%Y_%m_%d_%H%M")

# %% [markdown]
# ### create the first and the last (much needed files)
# <hr style="margin-top:0px;height:4px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %%
create_all_templates(general_vars_dic_new)
# Out:
# {% extends "core/detail_base_general.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'polity_research_assistant-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'polity_research_assistants' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_research_assistants_all' %}?orderby=polity_ra&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Polity ra
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if object.tag == 'DSP' %}
# text-danger
# {% elif object.tag == 'SSP' %}
# text-warning
# {% elif object.tag == 'UNK' %}
# text-secondary
# {% elif object.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6>{{ object.polity_ra }}</h6>
# <p> <small>{% if object.tag == "DSP" %}
#     <span class="badge rounded-pill bg-danger">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "SSP" %}
#      <span class="badge rounded-pill bg-warning text-dark">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "UNK" %}
#     <span class="badge rounded-pill bg-secondary">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "IFR" %}
#     <span class="badge rounded-pill bg-primary">{{ object.get_tag_display }}</span>
#     {% else  %}
#     <span class="badge rounded-pill bg-success">{{ object.get_tag_display }}</span>
#     {% endif %}</small></p>
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.polity_ra|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.polity_ra|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% block delete_button %}
#     <a href="{% url 'polity_research_assistant-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'polity_research_assistant-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'polity_research_assistant-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
#     <a href="{% url 'polity_research_assistants_all' %}" class="btn btn-warning mx-3 my-4 float-end"><i class="fa-solid fa-table-list"></i> &nbsp; See One-Page Mode</a>
#
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'polity_research_assistant-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_research_assistants_all' %}?orderby=polity_ra&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Polity ra
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Description
#     <sup>
#     <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
#     </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6 class="pt-3">{{ obj.polity_ra }}</h6>
# </td>
# {% autoescape off %}
# <td class="col-md-6"><small> {{ obj.comment }} </small></td>
# {% endautoescape %}
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;">
#         <div class="py-1">
#             <a href="{% url 'polity_research_assistant-update' obj.id %}"><button class="btn btn-warning btn-sm btn-block">Fact</button></a>
#         </div>
#         <div class="py-1">
#             <a href=""><button class="btn btn-danger btn-sm">Desc</button></a>
#         </div>
#     </td>
# {% endblock update_button %}
#
# {% extends "core/detail_base_general.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'polity_utm_zone-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'polity_utm_zones' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_utm_zones_all' %}?orderby=utm_zone&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Utm Zone
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if object.tag == 'DSP' %}
# text-danger
# {% elif object.tag == 'SSP' %}
# text-warning
# {% elif object.tag == 'UNK' %}
# text-secondary
# {% elif object.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6>{{ object.utm_zone }}</h6>
# <p> <small>{% if object.tag == "DSP" %}
#     <span class="badge rounded-pill bg-danger">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "SSP" %}
#      <span class="badge rounded-pill bg-warning text-dark">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "UNK" %}
#     <span class="badge rounded-pill bg-secondary">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "IFR" %}
#     <span class="badge rounded-pill bg-primary">{{ object.get_tag_display }}</span>
#     {% else  %}
#     <span class="badge rounded-pill bg-success">{{ object.get_tag_display }}</span>
#     {% endif %}</small></p>
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.utm_zone|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.utm_zone|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% block delete_button %}
#     <a href="{% url 'polity_utm_zone-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'polity_utm_zone-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'polity_utm_zone-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
#     <a href="{% url 'polity_utm_zones_all' %}" class="btn btn-warning mx-3 my-4 float-end"><i class="fa-solid fa-table-list"></i> &nbsp; See One-Page Mode</a>
#
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'polity_utm_zone-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_utm_zones_all' %}?orderby=utm_zone&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Utm Zone
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Description
#     <sup>
#     <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
#     </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6 class="pt-3">{{ obj.utm_zone }}</h6>
# </td>
# {% autoescape off %}
# <td class="col-md-6"><small> {{ obj.comment }} </small></td>
# {% endautoescape %}
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;">
#         <div class="py-1">
#             <a href="{% url 'polity_utm_zone-update' obj.id %}"><button class="btn btn-warning btn-sm btn-block">Fact</button></a>
#         </div>
#         <div class="py-1">
#             <a href=""><button class="btn btn-danger btn-sm">Desc</button></a>
#         </div>
#     </td>
# {% endblock update_button %}
#
# {% extends "core/detail_base_general.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'polity_original_name-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'polity_original_names' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_original_names_all' %}?orderby=original_name&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Original Name
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if object.tag == 'DSP' %}
# text-danger
# {% elif object.tag == 'SSP' %}
# text-warning
# {% elif object.tag == 'UNK' %}
# text-secondary
# {% elif object.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6>{{ object.original_name }}</h6>
# <p> <small>{% if object.tag == "DSP" %}
#     <span class="badge rounded-pill bg-danger">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "SSP" %}
#      <span class="badge rounded-pill bg-warning text-dark">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "UNK" %}
#     <span class="badge rounded-pill bg-secondary">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "IFR" %}
#     <span class="badge rounded-pill bg-primary">{{ object.get_tag_display }}</span>
#     {% else  %}
#     <span class="badge rounded-pill bg-success">{{ object.get_tag_display }}</span>
#     {% endif %}</small></p>
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.original_name|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.original_name|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% block delete_button %}
#     <a href="{% url 'polity_original_name-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'polity_original_name-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'polity_original_name-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
#     <a href="{% url 'polity_original_names_all' %}" class="btn btn-warning mx-3 my-4 float-end"><i class="fa-solid fa-table-list"></i> &nbsp; See One-Page Mode</a>
#
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'polity_original_name-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_original_names_all' %}?orderby=original_name&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Original Name
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Description
#     <sup>
#     <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
#     </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6 class="pt-3">{{ obj.original_name }}</h6>
# </td>
# {% autoescape off %}
# <td class="col-md-6"><small> {{ obj.comment }} </small></td>
# {% endautoescape %}
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;">
#         <div class="py-1">
#             <a href="{% url 'polity_original_name-update' obj.id %}"><button class="btn btn-warning btn-sm btn-block">Fact</button></a>
#         </div>
#         <div class="py-1">
#             <a href=""><button class="btn btn-danger btn-sm">Desc</button></a>
#         </div>
#     </td>
# {% endblock update_button %}
#
# {% extends "core/detail_base_general.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'polity_alternative_name-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'polity_alternative_names' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_alternative_names_all' %}?orderby=alternative_name&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Alternative Name
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if object.tag == 'DSP' %}
# text-danger
# {% elif object.tag == 'SSP' %}
# text-warning
# {% elif object.tag == 'UNK' %}
# text-secondary
# {% elif object.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6>{{ object.alternative_name }}</h6>
# <p> <small>{% if object.tag == "DSP" %}
#     <span class="badge rounded-pill bg-danger">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "SSP" %}
#      <span class="badge rounded-pill bg-warning text-dark">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "UNK" %}
#     <span class="badge rounded-pill bg-secondary">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "IFR" %}
#     <span class="badge rounded-pill bg-primary">{{ object.get_tag_display }}</span>
#     {% else  %}
#     <span class="badge rounded-pill bg-success">{{ object.get_tag_display }}</span>
#     {% endif %}</small></p>
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.alternative_name|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.alternative_name|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% block delete_button %}
#     <a href="{% url 'polity_alternative_name-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'polity_alternative_name-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'polity_alternative_name-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
#     <a href="{% url 'polity_alternative_names_all' %}" class="btn btn-warning mx-3 my-4 float-end"><i class="fa-solid fa-table-list"></i> &nbsp; See One-Page Mode</a>
#
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'polity_alternative_name-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_alternative_names_all' %}?orderby=alternative_name&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Alternative Name
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Description
#     <sup>
#     <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
#     </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6 class="pt-3">{{ obj.alternative_name }}</h6>
# </td>
# {% autoescape off %}
# <td class="col-md-6"><small> {{ obj.comment }} </small></td>
# {% endautoescape %}
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;">
#         <div class="py-1">
#             <a href="{% url 'polity_alternative_name-update' obj.id %}"><button class="btn btn-warning btn-sm btn-block">Fact</button></a>
#         </div>
#         <div class="py-1">
#             <a href=""><button class="btn btn-danger btn-sm">Desc</button></a>
#         </div>
#     </td>
# {% endblock update_button %}
#
# {% extends "core/detail_base_general.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'polity_peak_years-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'polity_peak_yearss' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_peak_yearss_all' %}?orderby=peak_year_from&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Peak Year from
# </th>
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_peak_yearss_all' %}?orderby=peak_year_to&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Peak Year to
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if object.tag == 'DSP' %}
# text-danger
# {% elif object.tag == 'SSP' %}
# text-warning
# {% elif object.tag == 'UNK' %}
# text-secondary
# {% elif object.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6>{{ object.peak_year_from }}</h6>
# <p> <small>{% if object.tag == "DSP" %}
#     <span class="badge rounded-pill bg-danger">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "SSP" %}
#      <span class="badge rounded-pill bg-warning text-dark">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "UNK" %}
#     <span class="badge rounded-pill bg-secondary">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "IFR" %}
#     <span class="badge rounded-pill bg-primary">{{ object.get_tag_display }}</span>
#     {% else  %}
#     <span class="badge rounded-pill bg-success">{{ object.get_tag_display }}</span>
#     {% endif %}</small></p>
# </td>
#
# <td class = "{% if object.tag == 'DSP' %}
# text-danger
# {% elif object.tag == 'SSP' %}
# text-warning
# {% elif object.tag == 'UNK' %}
# text-secondary
# {% elif object.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6>{{ object.peak_year_to }}</h6>
# <p> <small>{% if object.tag == "DSP" %}
#     <span class="badge rounded-pill bg-danger">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "SSP" %}
#      <span class="badge rounded-pill bg-warning text-dark">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "UNK" %}
#     <span class="badge rounded-pill bg-secondary">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "IFR" %}
#     <span class="badge rounded-pill bg-primary">{{ object.get_tag_display }}</span>
#     {% else  %}
#     <span class="badge rounded-pill bg-success">{{ object.get_tag_display }}</span>
#     {% endif %}</small></p>
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.peak_year_from|as_crispy_field }}
#     </div>
#
#
# <div class="col-md-3 mb-2">
# {{ form.peak_year_to|as_crispy_field }}
# </div>
# {% endblock extra_vars %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.peak_year_from|as_crispy_field }}
#     </div>
#
#
# <div class="col-md-3 mb-2">
# {{ form.peak_year_to|as_crispy_field }}
# </div>
# {% endblock extra_vars %}
#
# {% block delete_button %}
#     <a href="{% url 'polity_peak_years-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'polity_peak_years-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'polity_peak_years-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
#     <a href="{% url 'polity_peak_yearss_all' %}" class="btn btn-warning mx-3 my-4 float-end"><i class="fa-solid fa-table-list"></i> &nbsp; See One-Page Mode</a>
#
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'polity_peak_years-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_peak_yearss_all' %}?orderby=peak_year_from&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Peak Year from
# </th>
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_peak_yearss_all' %}?orderby=peak_year_to&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Peak Year to
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Description
#     <sup>
#     <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
#     </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6 class="pt-3">{{ obj.peak_year_from }}</h6>
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6 class="pt-3">{{ obj.peak_year_to }}</h6>
# </td>
# {% autoescape off %}
# <td class="col-md-6"><small> {{ obj.comment }} </small></td>
# {% endautoescape %}
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;">
#         <div class="py-1">
#             <a href="{% url 'polity_peak_years-update' obj.id %}"><button class="btn btn-warning btn-sm btn-block">Fact</button></a>
#         </div>
#         <div class="py-1">
#             <a href=""><button class="btn btn-danger btn-sm">Desc</button></a>
#         </div>
#     </td>
# {% endblock update_button %}
#
# {% extends "core/detail_base_general.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'polity_duration-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'polity_durations' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_durations_all' %}?orderby=polity_year_from&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Polity Year from
# </th>
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_durations_all' %}?orderby=polity_year_to&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Polity Year to
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if object.tag == 'DSP' %}
# text-danger
# {% elif object.tag == 'SSP' %}
# text-warning
# {% elif object.tag == 'UNK' %}
# text-secondary
# {% elif object.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6>{{ object.polity_year_from }}</h6>
# <p> <small>{% if object.tag == "DSP" %}
#     <span class="badge rounded-pill bg-danger">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "SSP" %}
#      <span class="badge rounded-pill bg-warning text-dark">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "UNK" %}
#     <span class="badge rounded-pill bg-secondary">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "IFR" %}
#     <span class="badge rounded-pill bg-primary">{{ object.get_tag_display }}</span>
#     {% else  %}
#     <span class="badge rounded-pill bg-success">{{ object.get_tag_display }}</span>
#     {% endif %}</small></p>
# </td>
#
# <td class = "{% if object.tag == 'DSP' %}
# text-danger
# {% elif object.tag == 'SSP' %}
# text-warning
# {% elif object.tag == 'UNK' %}
# text-secondary
# {% elif object.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6>{{ object.polity_year_to }}</h6>
# <p> <small>{% if object.tag == "DSP" %}
#     <span class="badge rounded-pill bg-danger">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "SSP" %}
#      <span class="badge rounded-pill bg-warning text-dark">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "UNK" %}
#     <span class="badge rounded-pill bg-secondary">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "IFR" %}
#     <span class="badge rounded-pill bg-primary">{{ object.get_tag_display }}</span>
#     {% else  %}
#     <span class="badge rounded-pill bg-success">{{ object.get_tag_display }}</span>
#     {% endif %}</small></p>
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.polity_year_from|as_crispy_field }}
#     </div>
#
#
# <div class="col-md-3 mb-2">
# {{ form.polity_year_to|as_crispy_field }}
# </div>
# {% endblock extra_vars %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.polity_year_from|as_crispy_field }}
#     </div>
#
#
# <div class="col-md-3 mb-2">
# {{ form.polity_year_to|as_crispy_field }}
# </div>
# {% endblock extra_vars %}
#
# {% block delete_button %}
#     <a href="{% url 'polity_duration-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'polity_duration-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'polity_duration-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
#     <a href="{% url 'polity_durations_all' %}" class="btn btn-warning mx-3 my-4 float-end"><i class="fa-solid fa-table-list"></i> &nbsp; See One-Page Mode</a>
#
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'polity_duration-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_durations_all' %}?orderby=polity_year_from&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Polity Year from
# </th>
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_durations_all' %}?orderby=polity_year_to&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Polity Year to
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Description
#     <sup>
#     <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
#     </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6 class="pt-3">{{ obj.polity_year_from }}</h6>
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6 class="pt-3">{{ obj.polity_year_to }}</h6>
# </td>
# {% autoescape off %}
# <td class="col-md-6"><small> {{ obj.comment }} </small></td>
# {% endautoescape %}
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;">
#         <div class="py-1">
#             <a href="{% url 'polity_duration-update' obj.id %}"><button class="btn btn-warning btn-sm btn-block">Fact</button></a>
#         </div>
#         <div class="py-1">
#             <a href=""><button class="btn btn-danger btn-sm">Desc</button></a>
#         </div>
#     </td>
# {% endblock update_button %}
#
# {% extends "core/detail_base_general.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'polity_degree_of_centralization-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'polity_degree_of_centralizations' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_degree_of_centralizations_all' %}?orderby=degree_of_centralization&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Degree of Centralization
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if object.tag == 'DSP' %}
# text-danger
# {% elif object.tag == 'SSP' %}
# text-warning
# {% elif object.tag == 'UNK' %}
# text-secondary
# {% elif object.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6>{{ object.degree_of_centralization }}</h6>
# <p> <small>{% if object.tag == "DSP" %}
#     <span class="badge rounded-pill bg-danger">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "SSP" %}
#      <span class="badge rounded-pill bg-warning text-dark">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "UNK" %}
#     <span class="badge rounded-pill bg-secondary">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "IFR" %}
#     <span class="badge rounded-pill bg-primary">{{ object.get_tag_display }}</span>
#     {% else  %}
#     <span class="badge rounded-pill bg-success">{{ object.get_tag_display }}</span>
#     {% endif %}</small></p>
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.degree_of_centralization|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.degree_of_centralization|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% block delete_button %}
#     <a href="{% url 'polity_degree_of_centralization-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'polity_degree_of_centralization-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'polity_degree_of_centralization-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
#     <a href="{% url 'polity_degree_of_centralizations_all' %}" class="btn btn-warning mx-3 my-4 float-end"><i class="fa-solid fa-table-list"></i> &nbsp; See One-Page Mode</a>
#
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'polity_degree_of_centralization-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_degree_of_centralizations_all' %}?orderby=degree_of_centralization&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Degree of Centralization
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Description
#     <sup>
#     <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
#     </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6 class="pt-3">{{ obj.degree_of_centralization }}</h6>
# </td>
# {% autoescape off %}
# <td class="col-md-6"><small> {{ obj.comment }} </small></td>
# {% endautoescape %}
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;">
#         <div class="py-1">
#             <a href="{% url 'polity_degree_of_centralization-update' obj.id %}"><button class="btn btn-warning btn-sm btn-block">Fact</button></a>
#         </div>
#         <div class="py-1">
#             <a href=""><button class="btn btn-danger btn-sm">Desc</button></a>
#         </div>
#     </td>
# {% endblock update_button %}
#
# {% extends "core/detail_base_general.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'polity_suprapolity_relations-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'polity_suprapolity_relationss' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_suprapolity_relationss_all' %}?orderby=supra_polity_relations&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Supra Polity Relations
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if object.tag == 'DSP' %}
# text-danger
# {% elif object.tag == 'SSP' %}
# text-warning
# {% elif object.tag == 'UNK' %}
# text-secondary
# {% elif object.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6>{{ object.supra_polity_relations }}</h6>
# <p> <small>{% if object.tag == "DSP" %}
#     <span class="badge rounded-pill bg-danger">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "SSP" %}
#      <span class="badge rounded-pill bg-warning text-dark">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "UNK" %}
#     <span class="badge rounded-pill bg-secondary">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "IFR" %}
#     <span class="badge rounded-pill bg-primary">{{ object.get_tag_display }}</span>
#     {% else  %}
#     <span class="badge rounded-pill bg-success">{{ object.get_tag_display }}</span>
#     {% endif %}</small></p>
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.supra_polity_relations|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.supra_polity_relations|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% block delete_button %}
#     <a href="{% url 'polity_suprapolity_relations-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'polity_suprapolity_relations-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'polity_suprapolity_relations-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
#     <a href="{% url 'polity_suprapolity_relationss_all' %}" class="btn btn-warning mx-3 my-4 float-end"><i class="fa-solid fa-table-list"></i> &nbsp; See One-Page Mode</a>
#
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'polity_suprapolity_relations-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_suprapolity_relationss_all' %}?orderby=supra_polity_relations&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Supra Polity Relations
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Description
#     <sup>
#     <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
#     </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6 class="pt-3">{{ obj.supra_polity_relations }}</h6>
# </td>
# {% autoescape off %}
# <td class="col-md-6"><small> {{ obj.comment }} </small></td>
# {% endautoescape %}
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;">
#         <div class="py-1">
#             <a href="{% url 'polity_suprapolity_relations-update' obj.id %}"><button class="btn btn-warning btn-sm btn-block">Fact</button></a>
#         </div>
#         <div class="py-1">
#             <a href=""><button class="btn btn-danger btn-sm">Desc</button></a>
#         </div>
#     </td>
# {% endblock update_button %}
#
# {% extends "core/detail_base_general.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'polity_capital-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'polity_capitals' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_capitals_all' %}?orderby=capital&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Capital
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if object.tag == 'DSP' %}
# text-danger
# {% elif object.tag == 'SSP' %}
# text-warning
# {% elif object.tag == 'UNK' %}
# text-secondary
# {% elif object.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6>{{ object.capital }}</h6>
# <p> <small>{% if object.tag == "DSP" %}
#     <span class="badge rounded-pill bg-danger">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "SSP" %}
#      <span class="badge rounded-pill bg-warning text-dark">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "UNK" %}
#     <span class="badge rounded-pill bg-secondary">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "IFR" %}
#     <span class="badge rounded-pill bg-primary">{{ object.get_tag_display }}</span>
#     {% else  %}
#     <span class="badge rounded-pill bg-success">{{ object.get_tag_display }}</span>
#     {% endif %}</small></p>
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.capital|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.capital|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% block delete_button %}
#     <a href="{% url 'polity_capital-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'polity_capital-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'polity_capital-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
#     <a href="{% url 'polity_capitals_all' %}" class="btn btn-warning mx-3 my-4 float-end"><i class="fa-solid fa-table-list"></i> &nbsp; See One-Page Mode</a>
#
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'polity_capital-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_capitals_all' %}?orderby=capital&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Capital
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Description
#     <sup>
#     <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
#     </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6 class="pt-3">{{ obj.capital }}</h6>
# </td>
# {% autoescape off %}
# <td class="col-md-6"><small> {{ obj.comment }} </small></td>
# {% endautoescape %}
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;">
#         <div class="py-1">
#             <a href="{% url 'polity_capital-update' obj.id %}"><button class="btn btn-warning btn-sm btn-block">Fact</button></a>
#         </div>
#         <div class="py-1">
#             <a href=""><button class="btn btn-danger btn-sm">Desc</button></a>
#         </div>
#     </td>
# {% endblock update_button %}
#
# {% extends "core/detail_base_general.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'polity_language-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'polity_languages' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# ...
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_alternate_religions_all' %}?orderby=alternate_religion&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Alternate Religion
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Description
#     <sup>
#     <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
#     </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6 class="pt-3">{{ obj.alternate_religion }}</h6>
# </td>
# {% autoescape off %}
# <td class="col-md-6"><small> {{ obj.comment }} </small></td>
# {% endautoescape %}
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;">
#         <div class="py-1">
#             <a href="{% url 'polity_alternate_religion-update' obj.id %}"><button class="btn btn-warning btn-sm btn-block">Fact</button></a>
#         </div>
#         <div class="py-1">
#             <a href=""><button class="btn btn-danger btn-sm">Desc</button></a>
#         </div>
#     </td>
# {% endblock update_button %}
#
# {% extends "core/detail_base_general.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'polity_expert-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'polity_experts' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_experts_all' %}?orderby=expert&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Expert
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if object.tag == 'DSP' %}
# text-danger
# {% elif object.tag == 'SSP' %}
# text-warning
# {% elif object.tag == 'UNK' %}
# text-secondary
# {% elif object.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6>{{ object.expert }}</h6>
# <p> <small>{% if object.tag == "DSP" %}
#     <span class="badge rounded-pill bg-danger">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "SSP" %}
#      <span class="badge rounded-pill bg-warning text-dark">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "UNK" %}
#     <span class="badge rounded-pill bg-secondary">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "IFR" %}
#     <span class="badge rounded-pill bg-primary">{{ object.get_tag_display }}</span>
#     {% else  %}
#     <span class="badge rounded-pill bg-success">{{ object.get_tag_display }}</span>
#     {% endif %}</small></p>
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.expert|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.expert|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% block delete_button %}
#     <a href="{% url 'polity_expert-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'polity_expert-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'polity_expert-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
#     <a href="{% url 'polity_experts_all' %}" class="btn btn-warning mx-3 my-4 float-end"><i class="fa-solid fa-table-list"></i> &nbsp; See One-Page Mode</a>
#
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'polity_expert-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_experts_all' %}?orderby=expert&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Expert
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Description
#     <sup>
#     <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
#     </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6 class="pt-3">{{ obj.expert }}</h6>
# </td>
# {% autoescape off %}
# <td class="col-md-6"><small> {{ obj.comment }} </small></td>
# {% endautoescape %}
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;">
#         <div class="py-1">
#             <a href="{% url 'polity_expert-update' obj.id %}"><button class="btn btn-warning btn-sm btn-block">Fact</button></a>
#         </div>
#         <div class="py-1">
#             <a href=""><button class="btn btn-danger btn-sm">Desc</button></a>
#         </div>
#     </td>
# {% endblock update_button %}
#
# {% extends "core/detail_base_general.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'polity_editor-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'polity_editors' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_editors_all' %}?orderby=editor&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Editor
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if object.tag == 'DSP' %}
# text-danger
# {% elif object.tag == 'SSP' %}
# text-warning
# {% elif object.tag == 'UNK' %}
# text-secondary
# {% elif object.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6>{{ object.editor }}</h6>
# <p> <small>{% if object.tag == "DSP" %}
#     <span class="badge rounded-pill bg-danger">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "SSP" %}
#      <span class="badge rounded-pill bg-warning text-dark">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "UNK" %}
#     <span class="badge rounded-pill bg-secondary">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "IFR" %}
#     <span class="badge rounded-pill bg-primary">{{ object.get_tag_display }}</span>
#     {% else  %}
#     <span class="badge rounded-pill bg-success">{{ object.get_tag_display }}</span>
#     {% endif %}</small></p>
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.editor|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.editor|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% block delete_button %}
#     <a href="{% url 'polity_editor-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'polity_editor-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'polity_editor-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
#     <a href="{% url 'polity_editors_all' %}" class="btn btn-warning mx-3 my-4 float-end"><i class="fa-solid fa-table-list"></i> &nbsp; See One-Page Mode</a>
#
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'polity_editor-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_editors_all' %}?orderby=editor&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Editor
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Description
#     <sup>
#     <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
#     </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6 class="pt-3">{{ obj.editor }}</h6>
# </td>
# {% autoescape off %}
# <td class="col-md-6"><small> {{ obj.comment }} </small></td>
# {% endautoescape %}
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;">
#         <div class="py-1">
#             <a href="{% url 'polity_editor-update' obj.id %}"><button class="btn btn-warning btn-sm btn-block">Fact</button></a>
#         </div>
#         <div class="py-1">
#             <a href=""><button class="btn btn-danger btn-sm">Desc</button></a>
#         </div>
#     </td>
# {% endblock update_button %}
#
# {% extends "core/detail_base_general.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'polity_religious_tradition-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'polity_religious_traditions' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_religious_traditions_all' %}?orderby=religious_tradition&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Religious Tradition
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if object.tag == 'DSP' %}
# text-danger
# {% elif object.tag == 'SSP' %}
# text-warning
# {% elif object.tag == 'UNK' %}
# text-secondary
# {% elif object.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6>{{ object.religious_tradition }}</h6>
# <p> <small>{% if object.tag == "DSP" %}
#     <span class="badge rounded-pill bg-danger">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "SSP" %}
#      <span class="badge rounded-pill bg-warning text-dark">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "UNK" %}
#     <span class="badge rounded-pill bg-secondary">{{ object.get_tag_display }}</span>
#     {% elif  object.tag == "IFR" %}
#     <span class="badge rounded-pill bg-primary">{{ object.get_tag_display }}</span>
#     {% else  %}
#     <span class="badge rounded-pill bg-success">{{ object.get_tag_display }}</span>
#     {% endif %}</small></p>
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.religious_tradition|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% extends "core/form_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#
#     <div class="col-md-3 mb-2">
#         {{ form.religious_tradition|as_crispy_field }}
#     </div>
#
#
# {% endblock extra_vars %}
#
# {% block delete_button %}
#     <a href="{% url 'polity_religious_tradition-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base_general.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'polity_religious_tradition-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'polity_religious_tradition-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
#     <a href="{% url 'polity_religious_traditions_all' %}" class="btn btn-warning mx-3 my-4 float-end"><i class="fa-solid fa-table-list"></i> &nbsp; See One-Page Mode</a>
#
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'polity_religious_tradition-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-bold" style="text-align: center;" scope="col"><span>
#     <a href="{% url 'polity_religious_traditions_all' %}?orderby=religious_tradition&orderby2=tag"><i class="fa-solid fa-caret-down"></i></a>
# </span>Religious Tradition
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Description
#     <sup>
#     <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
#     </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">
# <h6 class="pt-3">{{ obj.religious_tradition }}</h6>
# </td>
# {% autoescape off %}
# <td class="col-md-6"><small> {{ obj.comment }} </small></td>
# {% endautoescape %}
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;">
#         <div class="py-1">
#             <a href="{% url 'polity_religious_tradition-update' obj.id %}"><button class="btn btn-warning btn-sm btn-block">Fact</button></a>
#         </div>
#         <div class="py-1">
#             <a href=""><button class="btn btn-danger btn-sm">Desc</button></a>
#         </div>
#     </td>
# {% endblock update_button %}

# %% [markdown]
# ### Run the bash script that does the transferring of the info
# <hr style="margin-top:0px;height:4px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %%
seshat_general = "/home/majid/dev/seshat/seshat/seshat/apps/general/"

#We don' need this for now as the other Templates are not ready yet
# !cp TEMPLATES/other_general_html_templates/*.html TEMPLATES/all_new_general_html_templates

# !mv /home/majid/dev/seshat/seshat/seshat/apps/general/templates/general /home/majid/dev/seshat/seshat/seshat/apps/general/templates/general_{nowstr}
# !mkdir /home/majid/dev/seshat/seshat/seshat/apps/general/templates/general
# !cp -R TEMPLATES/all_new_general_html_templates/* {seshat_general}templates/general/

# %% [markdown]
# # DO not Forget to migrate the changes and all to see all the new models.

# %%
1+2
# Out:
# 3

# %% [markdown]
# <hr style="margin-top:0px;height:66px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %% [markdown]
# <h1> SQL </h1>

# %% [markdown]
# # Var Hiers

# %%
from generating_utils import *

sql_folder = "all_sql_files"
make_sure_exists(sql_folder)
sql_file_name = sql_folder + "/all_sections.sql" 

sql_list_of_strings = sql_generator_for_varhiers_secs(varhiers_dic)
with open(sql_file_name , "w") as sql_file:
    for l in sql_list_of_strings:
        sql_file.write(l)
        print(l)
        sql_file.write("\n")

# %%
from generating_utils import *

sql_folder = "all_sql_files"
make_sure_exists(sql_folder)
sql_file_name = sql_folder + "/all_subsections.sql" 

sql_list_of_strings = sql_generator_for_varhiers_subs(varhiers_dic)
with open(sql_file_name , "w") as sql_file:
    for l in sql_list_of_strings:
        sql_file.write(l)
        print(l)
        sql_file.write("\n")

# %%
from generating_utils import *

sql_folder = "all_sql_files"
make_sure_exists(sql_folder)
sql_file_name = sql_folder + "/all_varhiers.sql" 

sql_list_of_strings = sql_generator_for_varhiers_varhiers(varhiers_dic)
with open(sql_file_name , "w") as sql_file:
    for l in sql_list_of_strings:
        sql_file.write(l)
        print(l)
        sql_file.write("\n")

# %% [markdown]
# <hr style="margin-top:0px;height:66px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %% [markdown]
# # SQL Generator For all vars

# %%
import csv
from generating_utils import *

from os import listdir
from os.path import isfile, join
mypath = "/home/majid/dev/seshat/jim_metadata/LAUNDRY/Qing_Datasets_CLEAN/"
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

for my_file in onlyfiles:
    print(my_file)
    my_file_address= mypath + my_file
    sql_folder = "all_sql_files_for_vars/"
    make_sure_exists(sql_folder)
    sql_file_name = sql_folder + my_file[:-4] + ".sql"

    sql_list_of_strings = sql_generator_for_a_var(my_file_address)
    with open(sql_file_name , "w") as sql_file:
        sql_file.write(sql_list_of_strings)

# %%
onlyfiles

# %%
import csv
from generating_utils import *

my_file_address="/home/majid/dev/seshat/jim_metadata/LAUNDRY/Qing_Datasets_CLEAN/df_arable_land_FROM_CrisisDB_agricultural_data_CLEAN.csv"

sql_folder = "all_sql_files"
make_sure_exists(sql_folder)
sql_file_name = sql_folder + "/test.sql" 

sql_list_of_strings = sql_generator_for_a_var(my_file_address)
with open(sql_file_name , "w") as sql_file:
    sql_file.write(sql_list_of_strings)

# %%
ali = "majid"

# %%
ali = "'" + ali + "'"

# %%
ali

# %% [markdown]
# #### Remember taht before we can create any SQL file, we have to clean the data separtaely, and we have to make sure that the data is compatible with the data mpodels that we have in our apps. Col_names and all the other details must be taken care of.
#
# ## `Good Food` for our SQL generator is the most important.

# %%
import pandas as pd
from generating_utils import *
import datetime

# %%
# We can have the list of all files and sheets
# and give them as input to the following function

#folder is decided inside the inner functions and is hardcoded
my_files_details = {
    "tax_burden.xlsx":                   ['Sheet1', 'Sheet2', 'Sheet3', 'Sheet4'],
    "annual_wages_in_silver_liang.xlsx": ['Sheet1_MCMA', 'Sheet2_MCMA'],
    "Chinas_GDP.xlsx":                   ['Sheet1', 'Sheet2', 'Sheet3', 'Sheet4', 'Sheet5'],
    "Famine_Disease_from_Qing_datasets_2_sheets.xlsx": ["Qing_Wages", "Qing_Famine_MCMA",
                                                       "PROBLEMATIC_Qing_Conflicts_COW",
                                                       "Qing_Disease_MCMA"],
    "Jinshi_examination.xlsx":           ['Sheet1_MCMA', 'Sheet2_MCMA', 'Sheet3_MCMA'],
    "Taiping_rebellion_leaders.xlsx":    ['Sheet1_MCMA',],
    "wages_of_workers.xlsx":             ['Sheet1_MCMA',],
}

# %%
# this will containn all the data in clean format in key value pairs
#    key: sheet_name
#    value: a df containing all the data in the file (accesseíble via an extra key for sheet)
my_good_dfs = read_and_save_all_excel_sheets_at_once(my_files_details)

# %%
# Example: (Note that the folder name is bypassed as we don't need it)
my_good_dfs['tax_burden.xlsx']['Sheet1']

# %% [markdown]
# #### Now we have all the data based on the sheet and file names and we can do all soirts of things with them as they are now panda data frames. We can also do the cleanings and replacements in the previous steps as we are saving the files.

# %%
sql_generator_for_all(my_files_details, my_good_dfs)

# %%
8+2

# %%
creator = "Majid"
year = "1988"
From = [None, 123, 135]
To = [None, 123, 136]
def test(x,y):
    if x == None and y==None:
        return '{2},{3}::::({0}_{1})'.format(creator, year, x, y)
    elif x == y or ((not y) and x):
        return '{2},{3}::::({0}_{1}, p. {2})'.format(creator, year, x, x)
    elif x == y or ((not x) and y):
        return '{2},{3}::::({0}_{1}, p. {3})'.format(creator, year, x, y)
    elif x and y:
        return '{2},{3}::::({0}_{1}, pp. {2}-{3})'.format(creator, year, x, y)
    else:
        return '{2},{3}::::({0}_{1})'.format(creator, year, x, y)
for i in From:
    for j in To:
        print(test(i,j))

# %%
None == None

# %%
from generating_utils import *

# %%
varhier_dic = {
    "sectionA": {
        "subsectionX": []
    },
}
for k, v in vars_dic.items():
    # has k been taken care of ? No.
    # make sure we can append without breaking
    if v["section"] and v["section"] not in varhier_dic.keys():
        varhier_dic[v["section"]] = {}
        
        if v["subsection"] in varhier_dic[v["section"]].keys():
            if not varhier_dic[v["section"]][v["subsection"]]:
                list_of_vars=[]
            if k not in varhier_dic[v["section"]][v["subsection"]]:
                list_of_vars=[]

# %%
varhier_dic = {
    "Other_Sections": {
        "Other_Subsections":[]
    }
}
for k, v in vars_dic.items():
    if v["section"] and v["section"] not in varhier_dic.keys():
        varhier_dic[v["section"]] = {}
        
for k, v in vars_dic.items():
    if v["subsection"] and v["subsection"] not in varhier_dic[v["section"]].keys():
        varhier_dic[v["section"]][v["subsection"]] = []
        
for k, v in vars_dic.items():
    if k not in varhier_dic[v["section"]][v["subsection"]]:
        my_list = [k.replace("_", " ").capitalize(), k+"s", k+"-create"]
        varhier_dic[v["section"]][v["subsection"]].append(my_list)

# %%
varhier_dic

# %% [markdown]
# ## Citation appender makeshift

# %%
from generating_utils import *
from CONSTS.models_vars import MODELS_IMPORTS, MODELS_FUNCTION_DEFINITIONS
import datetime

# %%
citation_id_finder('MM6AEU7H')

# %%
reference_id_finder('119')

# %%
# 975BEGKF (on AWS:)   e7c3e5f2-d092-4323-9088-31dad5296d44

# MM6AEU7H  (on AWS)     c2d5665f-d0a5-4318-ab1f-fe06a6a4717f

# %%
citation_appender_makeshift("total_population", range(1,32), "e7c3e5f2-d092-4323-9088-31dad5296d44")

# %%
citation_appender_makeshift("total_population", range(1,32), "e7c3e5f2-d092-4323-9088-31dad5296d44")

# %%
citation_appender_makeshift("drought_event", range(269,537), "c2d5665f-d0a5-4318-ab1f-fe06a6a4717f")
citation_appender_makeshift("locust_event", range(269,537), "c2d5665f-d0a5-4318-ab1f-fe06a6a4717f")
citation_appender_makeshift("crop_failure_event", range(269,537), "c2d5665f-d0a5-4318-ab1f-fe06a6a4717f")
citation_appender_makeshift("famine_event", range(269,537), "c2d5665f-d0a5-4318-ab1f-fe06a6a4717f")

# %%
citation_appender_makeshift("socioeconomic_turmoil_event", range(1,269), "c2d5665f-d0a5-4318-ab1f-fe06a6a4717f")
